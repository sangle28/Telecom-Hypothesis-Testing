# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Hello, Sang!</b> We're glad to see you in code-reviewer territory. You've done a great job on the project, but let's get to know each other and make it even better! We have our own atmosphere here and a few rules:
#
#
# 1. I work as a code reviewer, and my main goal is not to point out your mistakes, but to share my experience and help you become a data analyst.
# 2. We speak on a first-come-first-served basis.
# 3. if you want to write or ask a question, don't be shy. Just choose your color for your comment.
# 4. this is a training project, you don't have to be afraid of making a mistake.
# 5. You have an unlimited number of attempts to pass the project.
# 6. Let's Go!
#
#
# ---
# I'll be color-coding comments, please don't delete them:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# Needs fixing. The block requires some corrections. Work can't be accepted with the red comments.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Reviewer's comment №1__
#
#
# Remarks. Some recommendations.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №1__
#
# Success. Everything is done succesfully.
# </div>
#
# ---
#
# I suggest that we work on the project in dialogue: if you change something in the project or respond to my comments, write about it. It will be easier for me to track changes if you highlight your comments:
#
# <div class="alert alert-info"> <b>Student сomments:</b> Student answer..</div>
#
# All this will help to make the recheck of your project faster. If you have any questions about my comments, let me know, we'll figure it out together :)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №3__
#
#
# Could you please tell me why you unload a new dataset every time?
#
# It is necessary to unload data only once (!) and then work with this data from now on
#
# PS. I wrote to the tutor to contact you. Please wait for him. And I will wait for you on the review ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №4__
#
#
# Could you please tell me why you unload a new dataset every time?
#
# It is necessary to unload data only once (!) and then work with this data from now on
#
# PS. I wrote to the tutor to contact you. Please wait for him. And I will wait for you on the review ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №2__
#
#
# Right now you have all your code written in one cell. Please correct the design of the project
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №3__
#
# The code crashes with an error. Please fix it
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Which one is a better plan?
#
# You work as an analyst for the telecom operator Megaline. The company offers its clients two prepaid plans, Surf and Ultimate. The commercial department wants to know which of the plans brings in more revenue in order to adjust the advertising budget.
#
# You are going to carry out a preliminary analysis of the plans based on a relatively small client selection. You'll have the data on 500 Megaline clients: who the clients are, where they're from, which plan they use, and the number of calls they made and text messages they sent in 2018. Your job is to analyze the clients' behavior and determine which prepaid plan brings in more revenue.

# %% [markdown]
# [We've provided you with some commentary to guide your thinking as you complete this project. However, make sure to remove all the bracketed comments before submitting your project.]
#
# [Before you dive into analyzing your data, explain for yourself the purpose of the project and actions you plan to take.]
#
# [Please bear in mind that studying, amending, and analyzing data is an iterative process. It is normal to return to previous steps and correct/expand them to allow for further steps.]

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Reviewer's comment №1__
#
# An excellent practice is to describe the goal and main steps in your own words (a skill that will help a lot on a final project). It would be good to add the progress and purpose of the study.

# %% [markdown]
# ## Initialization

# %%
# Loading all the libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## Load data

# %%
# Load the data files into different DataFrames
calls = pd.read_csv('/datasets/megaline_calls.csv')
internet = pd.read_csv('/datasets/megaline_internet.csv')
messages = pd.read_csv('/datasets/megaline_messages.csv')
plans = pd.read_csv('/datasets/megaline_plans.csv')
users = pd.read_csv('/datasets/megaline_users.csv')

# %% [markdown]
# ## Prepare the data

# %% [markdown]
# [The data for this project is split into several tables. Explore each one to get an initial understanding of the data. Do necessary corrections to each table if necessary.]

# %% [markdown]
# ## Plans

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Reviewer's comment №1__
#
# All necessary libraries should be unloaded at the beginning of the project in one code cell

# %%
# Print a sample of data for plans
print(plans.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   usd_monthly_pay        2 non-null      int64
#  4   usd_per_gb             2 non-null      int64
#  5   usd_per_message        2 non-null      float64
#  6   usd_per_minute         2 non-null      float64
#  7   plan_name              2 non-null      object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 256.0+ bytes
# None

# %%
# Print a sample of data for plans
plans.head()
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %% [markdown]
# ## Fix data

# %% [markdown]
# [Fix obvious issues with the data given the initial observations.]

# %% [markdown]
# ## Enriched data

# %%
plans['gb_per_month_included'] = plans['mb_per_month_included'] / 1024
display(plans)
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name  \
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate
#
#    gb_per_month_included
# 0                   15.0
# 1                   30.0

# %% [markdown]
# ## Users

# %%
# Print the general/ summary information about the users' DataFrame
print(users.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   first_name  500 non-null    object
#  2   last_name   500 non-null    object
#  3   age         500 non-null    int64
#  4   city        500 non-null    object
#  5   reg_date    500 non-null    object
#  6   plan        500 non-null    object
#  7   churn_date  34 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
# None

# %%
# Print a sample of data for users
users.head()
# Out:
#    user_id first_name  last_name  age                                   city  \
# 0     1000   Anamaria      Bauer   45  Atlanta-Sandy Springs-Roswell, GA MSA
# 1     1001     Mickey  Wilkerson   28        Seattle-Tacoma-Bellevue, WA MSA
# 2     1002     Carlee    Hoffman   36   Las Vegas-Henderson-Paradise, NV MSA
# 3     1003   Reynaldo    Jenkins   52                          Tulsa, OK MSA
# 4     1004    Leonila   Thompson   40        Seattle-Tacoma-Bellevue, WA MSA
#
#      reg_date      plan churn_date
# 0  2018-12-24  ultimate        NaN
# 1  2018-08-13      surf        NaN
# 2  2018-10-21      surf        NaN
# 3  2018-01-28      surf        NaN
# 4  2018-05-23      surf        NaN

# %% [markdown]
# # Fix Data

# %% [markdown]
# [Fix obvious issues with the data given the intial observation]

# %%
# Updating 'reg_date' column to date data type
users['reg_date'] = pd.to_datetime(users['reg_date'], format='%Y-%m-%d')
display(users['reg_date'].sample(10, random_state=1))
# Out:
# 304   2018-10-28
# 340   2018-07-05
# 47    2018-06-16
# 67    2018-09-24
# 479   2018-11-12
# 485   2018-08-21
# 310   2018-11-29
# 31    2018-07-15
# 249   2018-05-14
# 90    2018-05-12
# Name: reg_date, dtype: datetime64[ns]

# %%
# Updating 'churn_date' column to date data type and filling NaT values
users['churn_date'] = pd.to_datetime(users['churn_date'], format='%Y-%m-%d').fillna(value='User has not stopped service')
display(users['churn_date'].sample(10, random_state=1))
display(users.dtypes)
# Out:
# 304    User has not stopped service
# 340    User has not stopped service
# 47     User has not stopped service
# 67              2018-11-24 00:00:00
# 479    User has not stopped service
# 485    User has not stopped service
# 310    User has not stopped service
# 31     User has not stopped service
# 249    User has not stopped service
# 90     User has not stopped service
# Name: churn_date, dtype: object
# user_id                int64
# first_name            object
# last_name             object
# age                    int64
# city                  object
# reg_date      datetime64[ns]
# plan                  object
# churn_date            object
# dtype: object

# %% [markdown]
# ## Enrich data

# %% [markdown]
# [Add additional factors to the data if you believe they might be useful.]

# %% [markdown]
# ## Calls

# %%
# Print the general/summary information about the calls' DataFrame
print(calls.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  object
#  3   duration   137735 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB
# None

# %%
# Print a sample of a data for cells
calls.head()
# Out:
#          id  user_id   call_date  duration
# 0   1000_93     1000  2018-12-27      8.52
# 1  1000_145     1000  2018-12-27     13.66
# 2  1000_247     1000  2018-12-27     14.48
# 3  1000_309     1000  2018-12-28      5.76
# 4  1000_380     1000  2018-12-30      4.22

# %% [markdown]
# [Describe what you see and notice in the general information and the printed data sample for the above price of data. Are there any issues (inappropriate data types, missing data etc) that may need further investigation and changes? How that cant be fix?

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# Your project is hard to read because there are no subheadings / comments are written in code, not in Markdown cells / no inferences.... Please use the project design guidelines to correct these shortcomings.
#
# In the form of comments to the code, you should write explanations why you used certain python methods, why you grouped the data, why you need slices, etc.
# Everything else - conclusions, recommendations, decisions made, pointing out anomalies found, analyzing graphs, etc. should be written in makdown cells. This way your project will be easier to read.

# %% [markdown]
# ## Fix data

# %%
# Updating 'call_date' column to date data type
calls['call_date'] = pd.to_datetime(calls['call_date'], format='%Y-%m-%d')
display(calls['call_date'].sample(10, random_state=1))
# Out:
# 106231   2018-12-17
# 109017   2018-10-20
# 76096    2018-09-24
# 106317   2018-12-03
# 98706    2018-10-16
# 50517    2018-11-18
# 13355    2018-10-03
# 50255    2018-12-28
# 129376   2018-07-27
# 51887    2018-12-22
# Name: call_date, dtype: datetime64[ns]

# %%
# Adding new column for rounding up duration
calls['duration_mins'] = calls['duration'].apply(np.ceil).astype('int')
display(calls.sample(10, random_state=1))
display(calls.dtypes)
# Out:
#               id  user_id  call_date  duration  duration_mins
# 106231  1374_327     1374 2018-12-17      1.17              2
# 109017   1385_87     1385 2018-10-20     14.02             15
# 76096   1268_600     1268 2018-09-24     12.21             13
# 106317  1375_219     1375 2018-12-03      7.03              8
# 98706     1354_6     1354 2018-10-16      6.21              7
# 50517    1182_90     1182 2018-11-18      1.96              2
# 13355   1057_234     1057 2018-10-03      0.00              0
# 50255   1181_604     1181 2018-12-28     11.65             12
# 129376  1465_773     1465 2018-07-27     12.75             13
# 51887    1187_80     1187 2018-12-22     14.22             15
# id                       object
# user_id                   int64
# call_date        datetime64[ns]
# duration                float64
# duration_mins             int64
# dtype: object

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №8__
#
# Good for you for using the np.ceil() method

# %% [markdown]
# ##  Enrich data

# %%
# Adding new month column for the month call was taken
calls['call_month'] = calls['call_date'].dt.month
display(calls.sample(10, random_state=1))
# Out:
#               id  user_id  call_date  duration  duration_mins  call_month
# 106231  1374_327     1374 2018-12-17      1.17              2          12
# 109017   1385_87     1385 2018-10-20     14.02             15          10
# 76096   1268_600     1268 2018-09-24     12.21             13           9
# 106317  1375_219     1375 2018-12-03      7.03              8          12
# 98706     1354_6     1354 2018-10-16      6.21              7          10
# 50517    1182_90     1182 2018-11-18      1.96              2          11
# 13355   1057_234     1057 2018-10-03      0.00              0          10
# 50255   1181_604     1181 2018-12-28     11.65             12          12
# 129376  1465_773     1465 2018-07-27     12.75             13           7
# 51887    1187_80     1187 2018-12-22     14.22             15          12

# %% [markdown]
# ## Messages

# %%
# Print the general/summary information about the users' DataFrame
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Fix data

# %%
# Updating 'message_date' column to date data type
messages['message_date'] = pd.to_datetime(messages['message_date'], format='%Y-%m-%d')
display(messages['message_date'].sample(10, random_state=1))
display(messages.dtypes)
# Out:
# 12922   2018-11-17
# 55949   2018-10-04
# 19111   2018-11-04
# 46123   2018-12-15
# 72141   2018-05-18
# 58237   2018-12-15
# 55621   2018-10-11
# 18826   2018-07-13
# 64105   2018-06-05
# 6990    2018-11-18
# Name: message_date, dtype: datetime64[ns]
# id                      object
# user_id                  int64
# message_date    datetime64[ns]
# dtype: object

# %% [markdown]
# ## Enrich data

# %% [markdown]
# Add additional factors to the data if you believe they might be useful.

# %%
# Adding new month column for the month message was sent
messages['message_month'] = messages['message_date'].dt.month
display(messages.sample(10, random_state=1))
# Out:
#              id  user_id message_date  message_month
# 12922  1084_162     1084   2018-11-17             11
# 55949   1354_99     1354   2018-10-04             10
# 19111  1123_180     1123   2018-11-04             11
# 46123   1314_11     1314   2018-12-15             12
# 72141  1467_473     1467   2018-05-18              5
# 58237   1369_38     1369   2018-12-15             12
# 55621  1349_433     1349   2018-10-11             10
# 18826   1122_55     1122   2018-07-13              7
# 64105  1408_230     1408   2018-06-05              6
# 6990   1057_314     1057   2018-11-18             11

# %% [markdown]
# ## Internet

# %%
# Print the general/ summary information about the internet DataFrame
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  object
#  3   mb_used       104825 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
# Print a sample of data for the internet traffic.
internet.head()
# Out:
#          id  user_id session_date  mb_used
# 0   1000_13     1000   2018-12-29    89.86
# 1  1000_204     1000   2018-12-31     0.00
# 2  1000_379     1000   2018-12-28   660.40
# 3  1000_413     1000   2018-12-26   270.99
# 4  1000_442     1000   2018-12-27   880.22

# %% [markdown]
# [Describe what you see and notice in the general information and the printed data sample for the above price of data. Are there any issues (inappropriate data types, missing data, etc) that may need further investigation and changes? How that can be fixed?]

# %% [markdown]
# ## Fix Data

# %% [markdown]
# [ Fix obvious issues with the data given the initial observations]

# %%
# Updating 'session_date' column to date data type
internet['session_date'] = pd.to_datetime(internet['session_date'], format='%Y-%m-%d')
display(internet['session_date'].sample(10, random_state=1))
display(internet.dtypes)
# Out:
# 13106   2018-09-15
# 70950   2018-09-28
# 6195    2018-12-27
# 2400    2018-06-26
# 25926   2018-12-16
# 63187   2018-07-08
# 16908   2018-12-12
# 64323   2018-12-20
# 95470   2018-08-13
# 55326   2018-12-18
# Name: session_date, dtype: datetime64[ns]
# id                      object
# user_id                  int64
# session_date    datetime64[ns]
# mb_used                float64
# dtype: object

# %%
# Checking for duplicate values
display(internet.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ## Enrich data

# %% [markdown]
# [Add additional factors to the data if you believe they might be useful]

# %%
# Adding new column for gigabytes used
internet['gb_used'] = internet['mb_used'] / 1000
display(internet.sample(10, random_state=1))
# Out:
#              id  user_id session_date  mb_used  gb_used
# 13106   1062_76     1062   2018-09-15   225.79  0.22579
# 70950  1331_201     1331   2018-09-28   169.69  0.16969
# 6195    1035_43     1035   2018-12-27   124.84  0.12484
# 2400   1011_140     1011   2018-06-26     0.00  0.00000
# 25926   1121_19     1121   2018-12-16   504.92  0.50492
# 63187  1291_312     1291   2018-07-08   289.98  0.28998
# 16908   1077_28     1077   2018-12-12   465.72  0.46572
# 64323  1295_223     1295   2018-12-20   549.30  0.54930
# 95470  1445_118     1445   2018-08-13   405.50  0.40550
# 55326  1251_137     1251   2018-12-18   285.50  0.28550

# %%
# Adding new column for rounding up gigabytes
internet['gb_used_rounded'] = internet['gb_used'].apply(np.ceil).astype('int')
display(calls.sample(10, random_state=1))
display(calls.dtypes)
# Out:
#               id  user_id  call_date  duration  duration_mins  call_month
# 106231  1374_327     1374 2018-12-17      1.17              2          12
# 109017   1385_87     1385 2018-10-20     14.02             15          10
# 76096   1268_600     1268 2018-09-24     12.21             13           9
# 106317  1375_219     1375 2018-12-03      7.03              8          12
# 98706     1354_6     1354 2018-10-16      6.21              7          10
# 50517    1182_90     1182 2018-11-18      1.96              2          11
# 13355   1057_234     1057 2018-10-03      0.00              0          10
# 50255   1181_604     1181 2018-12-28     11.65             12          12
# 129376  1465_773     1465 2018-07-27     12.75             13           7
# 51887    1187_80     1187 2018-12-22     14.22             15          12
# id                       object
# user_id                   int64
# call_date        datetime64[ns]
# duration                float64
# ...

# %%
# Adding new month column for month web session was open
internet['session_month'] = internet['session_date'].dt.month
display(internet.sample(10, random_state=1))
# Out:
#              id  user_id session_date  mb_used  gb_used  gb_used_rounded  \
# 13106   1062_76     1062   2018-09-15   225.79  0.22579                1
# 70950  1331_201     1331   2018-09-28   169.69  0.16969                1
# 6195    1035_43     1035   2018-12-27   124.84  0.12484                1
# 2400   1011_140     1011   2018-06-26     0.00  0.00000                0
# 25926   1121_19     1121   2018-12-16   504.92  0.50492                1
# 63187  1291_312     1291   2018-07-08   289.98  0.28998                1
# 16908   1077_28     1077   2018-12-12   465.72  0.46572                1
# 64323  1295_223     1295   2018-12-20   549.30  0.54930                1
# 95470  1445_118     1445   2018-08-13   405.50  0.40550                1
# 55326  1251_137     1251   2018-12-18   285.50  0.28550                1
#
#        session_month
# 13106              9
# 70950              9
# 6195              12
# 2400               6
# 25926             12
# 63187              7
# ...

# %% [markdown]
# ## Study Plan Conditions

# %% [markdown]
# [It is critical to understand how the plans work, how users are charged based on their plan subscirption. So, we suggest printing out the plan information to view their conditions once again.]

# %%
# Print out the plan conditions and make sure they are clear for you 
display(plans)
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name  \
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate
#
#    gb_per_month_included
# 0                   15.0
# 1                   30.0

# %% [markdown]
# ## Aggregate data per user
#
# [Now, as the data is clean, aggregate data per user per period in order to have just one record per user per period. It should ease the further analysis a lot.]

# %%
# Calculate the number of calls made by each user per month. Save the result.
num_calls_group = calls.groupby(by=['user_id', 'call_month'])['id'].count().rename('calls_per_month_per_user')
display(num_calls_group)
# Out:
# user_id  call_month
# 1000     12            16
# 1001     8             27
#          9             49
#          10            65
#          11            64
#                        ..
# 1498     12            39
# 1499     9             41
#          10            53
#          11            45
#          12            65
# Name: calls_per_month_per_user, Length: 2258, dtype: int64

# %%
print()
calls_df_test = calls[(calls['user_id'] == 1001) & (calls['call_month'] == 8)]['id'].count()
calls_group_test = num_calls_group.loc[1001, 8]
if calls_df_test == calls_group_test:
    print('Test passed! They match!')
else:
    print('Error!')
print()
print('calls_df_test: User 1001 in the month of August made', calls_df_test, 'calls.')
print('calls_group_test: User 1001 in the month of August made', calls_group_test, 'calls.')
# Out:
# Test passed! They match!
#
# calls_df_test: User 1001 in the month of August made 27 calls.
# calls_group_test: User 1001 in the month of August made 27 calls.

# %%
# Calculate the number of calls made by each user per month. Save the result.
num_calls_group = calls.groupby(by=['user_id', 'call_month'])['id'].count().rename('calls_per_month_per_user')
display(num_calls_group)
# Out:
# user_id  call_month
# 1000     12            16
# 1001     8             27
#          9             49
#          10            65
#          11            64
#                        ..
# 1498     12            39
# 1499     9             41
#          10            53
#          11            45
#          12            65
# Name: calls_per_month_per_user, Length: 2258, dtype: int64

# %%
print()
calls_df_test = calls[(calls['user_id'] == 1001) & (calls['call_month'] == 8)]['id'].count()
calls_group_test = num_calls_group.loc[1001, 8]
if calls_df_test == calls_group_test:
    print('Test passed! They match!')
else:
    print('Error!')
print()
print('calls_df_test: User 1001 in the month of August made', calls_df_test, 'calls.')
print('calls_group_test: User 1001 in the month of August made', calls_group_test, 'calls.')
# Out:
# Test passed! They match!
#
# calls_df_test: User 1001 in the month of August made 27 calls.
# calls_group_test: User 1001 in the month of August made 27 calls.

# %%
# Calculate the amount of minutes spent by each user per month. Save the result.
calls_minutes_group = calls.groupby(by=['user_id', 'call_month'])['duration_mins'].sum().rename('minutes_per_month_per_user')
display(calls_minutes_group)
# Out:
# user_id  call_month
# 1000     12            124
# 1001     8             182
#          9             315
#          10            393
#          11            426
#                       ...
# 1498     12            339
# 1499     9             346
#          10            385
#          11            308
#          12            496
# Name: minutes_per_month_per_user, Length: 2258, dtype: int64

# %%
print()
minutes_df_test = calls[(calls['user_id'] == 1001) & (calls['call_month'] == 8)]['duration_mins'].sum()
minutes_group_test = calls_minutes_group.loc[1001, 8]
if minutes_df_test == minutes_group_test:
    print('Test passed! They match!')
else:
    print('Error!')
print()
print('minutes_df_test: User 1001 in the month of August had', minutes_df_test, 'minutes of calls.')
print('minutes_group_test: User 1001 in the month of August had', minutes_group_test, 'minutes of calls.')
# Out:
# Test passed! They match!
#
# minutes_df_test: User 1001 in the month of August had 182 minutes of calls.
# minutes_group_test: User 1001 in the month of August had 182 minutes of calls.

# %%
# Calculate the number of messages sent by each user per month. Save the result.
num_messages_group = messages.groupby(['user_id', 'message_month'])['id'].count().rename('messages_per_month_per_user')
display(num_messages_group)
# Out:
# user_id  message_month
# 1000     12               11
# 1001     8                30
#          9                44
#          10               53
#          11               36
#                           ..
# 1496     9                21
#          10               18
#          11               13
#          12               11
# 1497     12               50
# Name: messages_per_month_per_user, Length: 1806, dtype: int64

# %%
print()
messages_df_test = messages[(messages['user_id'] == 1001) & (messages['message_month'] == 8)]['id'].count()
messages_group_test = num_messages_group.loc[1001, 8]
if messages_df_test == messages_group_test:
    print('Test passed! They match!')
else:
    print('Error!')
print()
print('messages_df_test: User 1001 in the month of August sent', messages_df_test, 'messages.')
print('messages_group_test: User 1001 in the month of August sent', messages_group_test, 'messages.')
# Out:
# Test passed! They match!
#
# messages_df_test: User 1001 in the month of August sent 30 messages.
# messages_group_test: User 1001 in the month of August sent 30 messages.

# %%
# Calculate the volume of internet traffic used by each user per month. Save the result.
volume_internet_group = internet.groupby(['user_id', 'session_month'])['gb_used_rounded'].sum().rename('gigabytes_per_month_per_user')
display(volume_internet_group)
# Out:
# user_id  session_month
# 1000     12                4
# 1001     8                21
#          9                41
#          10               50
#          11               49
#                           ..
# 1498     12               56
# 1499     9                37
#          10               52
#          11               43
#          12               58
# Name: gigabytes_per_month_per_user, Length: 2277, dtype: int64

# %%
print()
internet_df_test = internet[(internet['user_id'] == 1001) & (internet['session_month'] == 8)]['gb_used_rounded'].sum()
internet_group_test = volume_internet_group.loc[1001, 8]
if internet_df_test == internet_group_test:
    print('Test passed! They match!')
else:
    print('Error!')
print()
print('internet_df_test: User 1001 in the month of August used', internet_df_test, 'gigabytes of data.')
print('internet_group_test: User 1001 in the month of August used', internet_group_test, 'gigabytes of data.')
# Out:
# Test passed! They match!
#
# internet_df_test: User 1001 in the month of August used 21 gigabytes of data.
# internet_group_test: User 1001 in the month of August used 21 gigabytes of data.

# %% [markdown]
# [Put the aggregate data together into one DataFrame so that one record in it would represent what an unique user consumed in a given month.]

# %%
# Merge the data for calls, minutes, messages, internet based on user_id and month
users_total_usage = pd.concat([num_calls_group, calls_minutes_group, num_messages_group, volume_internet_group], axis='columns').reset_index()
users_total_usage.rename(columns = {"level_1": "month"}, inplace=True)
users_total_usage = users_total_usage.fillna(0)
display(users_total_usage)
# Out:
#       user_id  month  calls_per_month_per_user  minutes_per_month_per_user  \
# 0        1000     12                      16.0                       124.0
# 1        1001      8                      27.0                       182.0
# 2        1001      9                      49.0                       315.0
# 3        1001     10                      65.0                       393.0
# 4        1001     11                      64.0                       426.0
# ...       ...    ...                       ...                         ...
# 2288     1498     12                      39.0                       339.0
# 2289     1499      9                      41.0                       346.0
# 2290     1499     10                      53.0                       385.0
# 2291     1499     11                      45.0                       308.0
# 2292     1499     12                      65.0                       496.0
#
#       messages_per_month_per_user  gigabytes_per_month_per_user
# ...

# %%
# Add the plan information
users_plans_merge = users.merge(plans, left_on='plan', right_on='plan_name', how='left')
users_total_usage_and_plans = users_total_usage.merge(users_plans_merge, left_on='user_id', right_on='user_id', how='left')
display(users_total_usage_and_plans.sample(10, random_state=48))
# Out:
#       user_id  month  calls_per_month_per_user  minutes_per_month_per_user  \
# 2290     1499     10                      53.0                       385.0
# 2023     1435     10                      37.0                       301.0
# 923      1192     12                      87.0                       612.0
# 1526     1332      9                      49.0                       314.0
# 458      1098      9                      79.0                       550.0
# 362      1077      2                     111.0                       776.0
# 944      1196      6                      89.0                       648.0
# 881      1184     12                      90.0                       666.0
# 172      1043     10                      24.0                       188.0
# 487      1102     12                      60.0                       430.0
#
#       messages_per_month_per_user  gigabytes_per_month_per_user first_name  \
# ...

# %% [markdown]
# [Calculate the monthly revenue from each user (subtract the free package limit from the total number of calls, text messages, and data; multiply the result by the calling plan value; add the monthly charge depending on the calling plan). N.B. This might not be as trivial as just a couple of lines given the plan conditions! So, it's okay to spend some time on it.]

# %%
# Calculate the monthly revenue for each user (minutes surcharge)

def minutes_surcharge(df_1):
    minutes_used = df_1['minutes_per_month_per_user']
    minutes_included = df_1['minutes_included']
    minutes_difference = minutes_used - minutes_included
    
    if minutes_difference < 0:
        df_1['minutes_surcharge'] = 0
    else:
        df_1['minutes_surcharge'] = minutes_difference * df_1['usd_per_minute']
    return df_1
        
users_total_usage_and_plans = users_total_usage_and_plans.apply(minutes_surcharge, axis=1)
print(users_total_usage_and_plans[['user_id', 'month', 'minutes_per_month_per_user', 'minutes_included', 'usd_per_minute', 'minutes_surcharge']].sample(10, random_state=48))
# Out:
#       user_id  month  minutes_per_month_per_user  minutes_included  \
# 2290     1499     10                       385.0               500
# 2023     1435     10                       301.0              3000
# 923      1192     12                       612.0               500
# 1526     1332      9                       314.0               500
# 458      1098      9                       550.0               500
# 362      1077      2                       776.0              3000
# 944      1196      6                       648.0              3000
# 881      1184     12                       666.0              3000
# 172      1043     10                       188.0              3000
# 487      1102     12                       430.0              3000
#
#       usd_per_minute  minutes_surcharge
# 2290            0.03               0.00
# 2023            0.01               0.00
# 923             0.03               3.36
# 1526            0.03               0.00
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №8__
#
# Great code

# %%
# Calculate the monthly revenue for each user (messages surcharge)

def messages_surcharge(df_2):
    messages_used = df_2['messages_per_month_per_user']
    messages_included = df_2['messages_included']
    messages_difference = messages_used - messages_included
    
    if messages_difference < 0:
        df_2['messages_surcharge'] = 0
    else:
        df_2['messages_surcharge'] = messages_difference * df_2['usd_per_message']
    return df_2

users_total_usage_and_plans = users_total_usage_and_plans.apply(messages_surcharge, axis=1)
print(users_total_usage_and_plans[['user_id', 'month', 'messages_per_month_per_user', 'messages_included', 'usd_per_message', 'messages_surcharge']].sample(10, random_state=48))
# Out:
#       user_id  month  messages_per_month_per_user  messages_included  \
# 2290     1499     10                          0.0                 50
# 2023     1435     10                        128.0               1000
# 923      1192     12                         25.0                 50
# 1526     1332      9                          3.0                 50
# 458      1098      9                         99.0                 50
# 362      1077      2                         67.0               1000
# 944      1196      6                         34.0               1000
# 881      1184     12                         37.0               1000
# 172      1043     10                         87.0               1000
# 487      1102     12                         45.0               1000
#
#       usd_per_message  messages_surcharge
# 2290             0.03                0.00
# 2023             0.01                0.00
# 923              0.03                0.00
# ...

# %%
# Calculate the monthly revenue for each user (gigabytes surcharge)

def data_surcharge(df_3):
    gigabytes_used = df_3['gigabytes_per_month_per_user']
    gigabytes_included = df_3['gb_per_month_included']
    gigabytes_difference = gigabytes_used - gigabytes_included
    
    if gigabytes_difference < 0:
        df_3['gigabyte_surcharge'] = 0
    else:
        df_3['gigabyte_surcharge'] = gigabytes_difference * df_3['usd_per_gb']
    return df_3

users_total_usage_and_plans = users_total_usage_and_plans.apply(data_surcharge, axis=1)
print(users_total_usage_and_plans[['user_id', 'month', 'gigabytes_per_month_per_user', 'gb_per_month_included', 'usd_per_gb', 'gigabyte_surcharge']].sample(10, random_state=48))
# Out:
#       user_id  month  gigabytes_per_month_per_user  gb_per_month_included  \
# 2290     1499     10                          52.0                   15.0
# 2023     1435     10                          51.0                   30.0
# 923      1192     12                          20.0                   15.0
# 1526     1332      9                          57.0                   15.0
# 458      1098      9                          57.0                   15.0
# 362      1077      2                          40.0                   30.0
# 944      1196      6                          50.0                   30.0
# 881      1184     12                          20.0                   30.0
# 172      1043     10                          57.0                   30.0
# 487      1102     12                          16.0                   30.0
#
#       usd_per_gb  gigabyte_surcharge
# 2290          10               370.0
# 2023           7               147.0
# 923           10                50.0
# ...

# %%
# Calculate the monthly revenue for each user (total revenue)
users_total_usage_and_plans['total_revenue'] = users_total_usage_and_plans['minutes_surcharge'] + users_total_usage_and_plans['messages_surcharge'] + users_total_usage_and_plans['gigabyte_surcharge'] + users_total_usage_and_plans['usd_monthly_pay']
display(users_total_usage_and_plans.sample(10, random_state=48))
# Out:
#       user_id  month  calls_per_month_per_user  minutes_per_month_per_user  \
# 2290     1499     10                      53.0                       385.0
# 2023     1435     10                      37.0                       301.0
# 923      1192     12                      87.0                       612.0
# 1526     1332      9                      49.0                       314.0
# 458      1098      9                      79.0                       550.0
# 362      1077      2                     111.0                       776.0
# 944      1196      6                      89.0                       648.0
# 881      1184     12                      90.0                       666.0
# 172      1043     10                      24.0                       188.0
# 487      1102     12                      60.0                       430.0
#
#       messages_per_month_per_user  gigabytes_per_month_per_user first_name  \
# ...

# %% [markdown]
# ## Study user behaviour

# %% [markdown]
# [Calculate some useful descriptive statistics for the aggregated and merged data, which typically reveal an overall picture captured by the data. Draw useful plots to help the understanding. Given that the main task is to compare the plans and decide on which one is more profitable, the statistics and the plots should be calculated on a per-plan basis.]
#
# [There are relevant hints in the comments for Calls but they are not provided for Messages and Internet though the principle of statistical study is the same for them as for Calls.]

# %% [markdown]
# ### Calls

# %%
calls['call_date'] = pd.to_datetime(calls['call_date'])

# Extracting month
calls['month'] = calls['call_date'].dt.month
calls_summary = calls.groupby(['user_id', 'month'])['duration'].sum().reset_index(name='total_duration')
users = pd.read_csv('/datasets/megaline_users.csv')[['user_id', 'plan']]
calls_summary_with_plan = calls_summary.merge(users, on='user_id', how='left')
average_call_duration = calls_summary_with_plan.groupby(['plan','month'])['total_duration'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(data=average_call_duration, x='month', y='total_duration', hue='plan')
plt.title('Average Duration of Calls per Plan per Month')
plt.xlabel('Month')
plt.ylabel('Average Call Duration (minutes)')
plt.legend(title='Plan')
plt.show()

# %%
plt.figure(figsize=(10, 6))
ax = sns.histplot(data=calls_summary_with_plan, x='total_duration', hue='plan', bins=30, kde=True)

handles, labels = [], []
unique_plans = calls_summary_with_plan['plan'].unique()

# Generate a color palette for the number of unique plans
palette = sns.color_palette(n_colors=len(unique_plans))

for idx, plan in enumerate(unique_plans):
    handles.append(plt.Rectangle((0, 0), 1, 1, color=palette[idx]))
    labels.append(plan)

plt.legend(handles=handles, labels=labels, title='Plan')
plt.title('Total Call Duration per Plan per Month')
plt.xlabel('Total Call Duration (minutes)')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# [Calculate the mean and the variable of the call duration to reason on whether users on the different plans have different behaviours for their calls.]

# %%
# Calculate the mean and the variance of the monthly call duration
mean_duration_by_plan = calls_summary_with_plan.groupby('plan')['total_duration'].mean()
variance_duration_by_plan = calls_summary_with_plan.groupby('plan')['total_duration'].var()

print("Mean duration by plan:")
print(mean_duration_by_plan)

print("\nVariance of duration by plan:")
print(variance_duration_by_plan)
# Out:
# Mean duration by plan:
# plan
# surf        412.097890
# ultimate    410.180954
# Name: total_duration, dtype: float64
#
# Variance of duration by plan:
# plan
# surf        47001.254231
# ultimate    50510.631705
# Name: total_duration, dtype: float64

# %%
# Plot a boxplot to visualize the distribution of the monthly call duration
plt.figure(figsize=(10, 6))
sns.boxplot(data=calls_summary_with_plan, x='plan', y='total_duration') 
plt.title('Monthly Call Duration by Plan')
plt.xlabel('Plan')
plt.ylabel('Month Call Duration')
plt.show()

# %% [markdown]
# [Formulate conclusions on how the users behave in terms of calling. Is their behaviour different between the plans?]

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №8__
#
# It is better after each section, graph (or series of tests) to write a conclusion on the obtained data taking into account the set business task - so it is easier to read the project, because future colleagues or customers will not have to interpret the results of each section, test or graph themselves.
#
# ---
#
# In markdown ![image.png](attachment:image.png)

# %% [markdown]
# ### Messages

# %%
messages['month'] = pd.to_datetime(messages['message_date']).dt.month
messages_summary = messages.groupby(['user_id', 'month']).size().reset_index(name='messages')
messages_summary_with_plan = messages_summary.merge(users[['user_id', 'plan']], on='user_id', how='left')
average_messages_per_plan = messages_summary_with_plan.groupby(['plan', 'month'])['messages'].mean().reset_index()
#plotting
plt.figure(figsize=(10, 6))
sns.barplot(data=average_messages_per_plan, x='month', y='messages', hue='plan')
plt.title('Average Number of Messages per Plan Monthly')
plt.xlabel('Month')
plt.ylabel('Average Number of Messages')
plt.legend(title='Plan')
plt.show()

# %%
# Compare the amount of internet traffic consumed by users per plan
internet['month'] = pd.to_datetime(internet['session_date']).dt.month
internet_summary = internet.groupby(['user_id', 'month'])['mb_used'].sum().reset_index()
internet_summary_with_plan = internet_summary.merge(users[['user_id', 'plan']], on='user_id', how='left')
average_internet_usage_per_plan = internet_summary_with_plan.groupby(['plan', 'month'])['mb_used'].mean().reset_index()

#plotting
plt.figure(figsize=(10, 6))
sns.barplot(data=average_internet_usage_per_plan, x='month', y='mb_used', hue='plan')
plt.title('Average Number of Traffic per Plan Monthly')
plt.xlabel('Month')
plt.ylabel('Average Internet Traffic (MB)')
plt.legend(title='Plan')
plt.show()

# %%
average_messages_per_plan = messages_summary_with_plan.groupby('plan')['messages'].mean()
print("Average Internet Messages per Plan:")
print(average_messages_per_plan)

total_messages_per_plan = messages_summary_with_plan.groupby('plan')['messages'].sum()
print("\nTotal Number of Messages per Plan:")
print(total_messages_per_plan)

variance_messages_per_plan = messages_summary_with_plan.groupby('plan')['messages'].var()
print("\nVariance of Messsages per Plan:")
print(variance_messages_per_plan)
# Out:
# Average Internet Messages per Plan:
# plan
# surf        40.109656
# ultimate    46.296233
# Name: messages, dtype: float64
#
# Total Number of Messages per Plan:
# plan
# surf        49014
# ultimate    27037
# Name: messages, dtype: int64
#
# Variance of Messsages per Plan:
# plan
# surf        1091.344231
# ultimate    1085.183108
# Name: messages, dtype: float64

# %% [markdown]
# ## Internet

# %%
average_internet_usage_per_plan = internet_summary_with_plan.groupby('plan')['mb_used'].mean()
print("Average Internet Usage per Plan:")
print(average_internet_usage_per_plan)
# Out:
# Average Internet Usage per Plan:
# plan
# surf        16717.702137
# ultimate    17238.642253
# Name: mb_used, dtype: float64

# %%
total_internet_usage_per_plan = internet_summary_with_plan.groupby('plan')['mb_used'].sum()
print("\nTotal Internet usage per Plan:")
print(total_internet_usage_per_plan)
# Out:
# Total Internet usage per Plan:
# plan
# surf        26046179.93
# ultimate    12394583.78
# Name: mb_used, dtype: float64

# %%
variance_internet_usage_per_plan = internet_summary_with_plan.groupby('plan')['mb_used'].var()
print("\nVariance of Internet Usage per Plan:")
print(variance_internet_usage_per_plan)
# Out:
# Variance of Internet Usage per Plan:
# plan
# surf        6.216823e+07
# ultimate    6.132485e+07
# Name: mb_used, dtype: float64

# %%
# Compare the amount of internet traffic per each plan per each distinct month. Plot a bar plat to visualize it.

num_internet_sum = users_total_usage_and_plans.groupby(by=['plan', 'month'])['gigabytes_per_month_per_user'].sum().unstack(level=0)
num_internet_sum.index = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

num_internet_sum_plot = num_internet_sum.plot(title='Volume of internet traffic for each month',
                                       xlabel='Month',
                                       ylabel='Total number of gigabytes',
                                       figsize=(10,6),
                                       kind='bar',
                                       rot=45,
                                       stacked=False)
plt.legend(['Surf', 'Ultimate'])
plt.show()
print()

# %%
# Compare the amount of internet traffic consumed by users per plan

num_internet_surf = users_total_usage_and_plans[users_total_usage_and_plans['plan'] == 'surf']['gigabytes_per_month_per_user']
num_internet_ultimate = users_total_usage_and_plans[users_total_usage_and_plans['plan'] == 'ultimate']['gigabytes_per_month_per_user']
num_internet_surf.plot(title='Total number of gigabytes used per month',
                                      kind='hist',
                                      figsize=(10,6),
                                      alpha=0.5,
                                      bins=20)
num_internet_ultimate.plot(kind='hist',
                           alpha=0.5,
                           bins=20)
plt.legend(['Surf plan', 'Ultimate plan'])
plt.xlabel('Number of gigabytes per month')
plt.ylabel('Number of users')
plt.show()
display(num_internet_surf)
display(num_internet_ultimate)
# Out:
# 1       21.0
# 2       41.0
# 3       50.0
# 4       49.0
# 5       55.0
#         ...
# 2288    56.0
# 2289    37.0
# 2290    52.0
# 2291    43.0
# 2292    58.0
# Name: gigabytes_per_month_per_user, Length: 1573, dtype: float64
# 0        4.0
# 19       7.0
# 20      62.0
# 26      48.0
# 27      56.0
#         ...
# 2258    41.0
# 2259    44.0
# 2260    41.0
# 2261    36.0
# 2277    29.0
# Name: gigabytes_per_month_per_user, Length: 720, dtype: float64

# %%
# Calculate the mean and the variance of internet traffic per plan

print()
internet_mean_surf = users_total_usage_and_plans[users_total_usage_and_plans['plan'] == 'surf']['gigabytes_per_month_per_user'].mean().round(0)
print('Surf plan average gigabytes used per month:', internet_mean_surf, 'gigabytes')
print()
internet_mean_ultimate = users_total_usage_and_plans[users_total_usage_and_plans['plan'] =='ultimate']['gigabytes_per_month_per_user'].mean().round(0)
print('Ultimate plan average gigabytes sent per month:', internet_mean_ultimate, 'gigabytes')
print()
print()
internet_variance_surf = np.var(users_total_usage_and_plans[users_total_usage_and_plans['plan'] == 'surf']['gigabytes_per_month_per_user']).round(2)
print('Surf plan monthly gigabytes variance:', internet_variance_surf)
print()
internet_variance_ultimate = np.var(users_total_usage_and_plans[users_total_usage_and_plans['plan'] =='ultimate']['gigabytes_per_month_per_user']).round(2)
print('Ultimate plan monthly gigabytes variance:', internet_variance_ultimate)
print()
print()
# Out:
# Surf plan average gigabytes used per month: 40.0 gigabytes
#
# Ultimate plan average gigabytes sent per month: 41.0 gigabytes
#
#
# Surf plan monthly gigabytes variance: 320.75
#
# Ultimate plan monthly gigabytes variance: 275.14

# %% [markdown]
# [Formulate conclusions on how the users tend to consume the internet traffic? Is their behaviour different between the plans?]

# %% [markdown]
# ## Revenue

# %% [markdown]
# [Likewise you have studied the user behaviour, statistically describe the revenue between the plans.]

# %%
# Basic statistics: Total number of users on each plan, total revenue generated from each plan, 
# average revenue generated per user per plan

print()
total_users_surf = users_total_usage_and_plans[users_total_usage_and_plans['plan'] == 'surf']['plan'].count()
print('Total number of users on Surf plan:', total_users_surf, 'users')
total_users_ultimate =  users_total_usage_and_plans[users_total_usage_and_plans['plan'] == 'ultimate']['plan'].count()
print('Total number of users on Surf plan:', total_users_ultimate, 'users')
print()
print()
total_rev_surf = users_total_usage_and_plans[users_total_usage_and_plans['plan'] == 'surf']['total_revenue'].sum().round(2)
print('Total revenue from Surf plan:', total_rev_surf, 'dollars')
total_rev_ultimate = users_total_usage_and_plans[users_total_usage_and_plans['plan'] == 'ultimate']['total_revenue'].sum().round(2)
print('Total revenue from Ultimate plan:', total_rev_ultimate, 'dollars')
print()
print()
avg_rev_surf = (total_rev_surf / total_users_surf).round(2)
print('Average revenue per user on Surf plan:', avg_rev_surf, 'dollars')
avg_rev_ultimate = (total_rev_ultimate / total_users_ultimate).round(2)
print('Average revenue per user on Ultimate plan:', avg_rev_ultimate, 'dollars')
print()
# Out:
# Total number of users on Surf plan: 1573 users
# Total number of users on Surf plan: 720 users
#
#
# Total revenue from Surf plan: 445881.18 dollars
# Total revenue from Ultimate plan: 120575.0 dollars
#
#
# Average revenue per user on Surf plan: 283.46 dollars
# Average revenue per user on Ultimate plan: 167.47 dollars

# %%
# Compare percentages of users per month that had surchages for duration of calls, messages, and volume of internet traffic

print()
duration_zero_surf = users_total_usage_and_plans[(users_total_usage_and_plans['plan'] == 'surf') & (users_total_usage_and_plans['minutes_per_month_per_user'] > 500)]['minutes_per_month_per_user'].count()
duration_total_surf = users_total_usage_and_plans[(users_total_usage_and_plans['plan'] == 'surf')]['plan'].count()
print('Surf plan monthly call duration that was over 500 minutes:', (duration_zero_surf / duration_total_surf * 100).round(2), '%')
print()
duration_zero_ultimate = users_total_usage_and_plans[(users_total_usage_and_plans['plan'] == 'ultimate') & (users_total_usage_and_plans['minutes_per_month_per_user'] > 3000)]['minutes_per_month_per_user'].count()
duration_total_ultimate = users_total_usage_and_plans[(users_total_usage_and_plans['plan'] == 'ultimate')]['plan'].count()
print('Ultimate plan monthly call duration that was over 3000 minutes:', (duration_zero_ultimate / duration_total_ultimate * 100).round(2), '%')
print()
print()
messages_zero_surf = users_total_usage_and_plans[(users_total_usage_and_plans['plan'] == 'surf') & (users_total_usage_and_plans['messages_per_month_per_user'] > 50)]['messages_per_month_per_user'].count()
messages_total_surf = users_total_usage_and_plans[(users_total_usage_and_plans['plan'] == 'surf')]['plan'].count()
print('Surf plan percentage of users that sent more than 50 messages:', (messages_zero_surf / messages_total_surf * 100).round(2), '%')
print()
messages_zero_ultimate = users_total_usage_and_plans[(users_total_usage_and_plans['plan'] == 'ultimate') & (users_total_usage_and_plans['messages_per_month_per_user'] > 1000)]['messages_per_month_per_user'].count()
messages_total_ultimate = users_total_usage_and_plans[(users_total_usage_and_plans['plan'] == 'ultimate')]['plan'].count()
print('Ultimate plan percentage of users that more than 1000 messages:', (messages_zero_ultimate / messages_total_ultimate * 100).round(2), '%')
print()
print()
internet_zero_surf = users_total_usage_and_plans[(users_total_usage_and_plans['plan'] == 'surf') & (users_total_usage_and_plans['gigabytes_per_month_per_user'] > 15)]['gigabytes_per_month_per_user'].count()
internet_total_surf = users_total_usage_and_plans[(users_total_usage_and_plans['plan'] == 'surf')]['plan'].count()
print('Surf plan percentage of users that used more than 15 gigabytes:', (internet_zero_surf / internet_total_surf * 100).round(2), '%')
print()
internet_zero_ultimate = users_total_usage_and_plans[(users_total_usage_and_plans['plan'] == 'ultimate') & (users_total_usage_and_plans['gigabytes_per_month_per_user'] > 30)]['gigabytes_per_month_per_user'].count()
internet_total_ultimate = users_total_usage_and_plans[(users_total_usage_and_plans['plan'] == 'ultimate')]['plan'].count()
print('Ultimate plan percentage of users that used more than 30 gigabytes:', (internet_zero_ultimate / internet_total_ultimate * 100).round(2), '%')
print()
# Out:
# Surf plan monthly call duration that was over 500 minutes: 35.98 %
#
# Ultimate plan monthly call duration that was over 3000 minutes: 0.0 %
#
#
# Surf plan percentage of users that sent more than 50 messages: 21.61 %
#
# Ultimate plan percentage of users that more than 1000 messages: 0.0 %
#
#
# Surf plan percentage of users that used more than 15 gigabytes: 88.62 %
#
# Ultimate plan percentage of users that used more than 30 gigabytes: 77.5 %

# %%
# Compare the total revenue collected from users per plan. Plot a histogram to visualize it.

total_revenue_surf = users_total_usage_and_plans[users_total_usage_and_plans['plan'] == 'surf']['total_revenue']
total_revenue_ultimate = users_total_usage_and_plans[users_total_usage_and_plans['plan'] == 'ultimate']['total_revenue']
total_revenue_surf.plot(title='Total revenue from users per month',
                                      kind='hist',
                                      figsize=(10,6),
                                      alpha=0.5,
                                      bins=20)
total_revenue_ultimate.plot(kind='hist',
                           alpha=0.5,
                           bins=20)
plt.legend(['Surf plan', 'Ultimate plan'])
plt.xlabel('Total revenue collected per month')
plt.ylabel('Number of users')
plt.show()
display(total_revenue_surf)
display(total_revenue_ultimate)
# Out:
# 1        80.00
# 2       280.00
# 3       370.09
# 4       360.00
# 5       420.00
#          ...
# 2288    430.00
# 2289    240.00
# 2290    390.00
# 2291    300.00
# 2292    450.00
# Name: total_revenue, Length: 1573, dtype: float64
# 0        70.0
# 19       70.0
# 20      294.0
# 26      196.0
# 27      252.0
#         ...
# 2258    147.0
# 2259    168.0
# 2260    147.0
# 2261    112.0
# 2277     70.0
# Name: total_revenue, Length: 720, dtype: float64

# %% [markdown]
# [Formulate conclusions about how the revenue differs between the plans.]

# %% [markdown]
# ## Test statistical hypotheses

# %% [markdown]
# [Test the hypothesis that the average revenue from users in the NY-NJ area is different from that of the users from the other regions.]

# %% [markdown]
# [Formulate the null and the alternative hypotheses, choose the statistical test, decide on the alpha value.]

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №8__
#
# The wording of Ho and H1 is missing. Please add them to the section

# %%
# Test the hypotheses using a two-tailed t-test

rev_ultimate = users_total_usage_and_plans[users_total_usage_and_plans['plan'] == 'ultimate']['total_revenue']

# avg_rev_surf was created earlier for the average revenue for Surf users 
# Mean = 280.27

alpha_1 = 0.05

results_1 = stats.ttest_1samp(rev_ultimate, avg_rev_surf)

print()
print('p-value: ', results_1.pvalue)
print()
if (results_1.pvalue < alpha_1):
    print('We reject the null hypothesis')
else:
    print("We can't reject the null hypothesis")
print()
# Out:
# p-value:  8.502565137546417e-160
#
# We reject the null hypothesis

# %% [markdown]
# ## Hypotheses
#
# [The average revenue from users of the Ultimate plan is equal to that of the Surf plan. Alternative Hypothesis: The average revenue from users of the Ultimate plan is different from that of the surf plan.]
#
# [We will use an independent samples t-test to compare the average revenues because it is approiate for comparing the means of two distinct groups. The nan_policy='omit' parameter will included to ensure that an NaN values are automatically excluded from the analysis.]

# %%
# Test the hypotheses using a two-tailed t-test

NY_NJ_rev_mean = users_total_usage_and_plans[users_total_usage_and_plans['city'].str.contains('NY-NJ')]['total_revenue'].mean()
other_regions_rev_mean = users_total_usage_and_plans[~users_total_usage_and_plans['city'].str.contains('NY-NJ')]['total_revenue'].mean()
NY_NJ_rev = users_total_usage_and_plans[users_total_usage_and_plans['city'].str.contains('NY-NJ')]['total_revenue']
other_regions_rev = users_total_usage_and_plans[~users_total_usage_and_plans['city'].str.contains('NY-NJ')][ 'total_revenue']


alpha_2 = 0.05

results_2 = stats.ttest_1samp(NY_NJ_rev, other_regions_rev_mean)

print()
print('p-value: ', results_2.pvalue)
print()
if (results_2.pvalue < alpha_2):
    print('We reject the null hypothesis')
else:
    print("We can't reject the null hypothesis")
print()
# Out:
# p-value:  0.0017708330457341583
#
# We reject the null hypothesis

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №8__
#
#
# It would be nice to add an overall output for the projec
# </div>
